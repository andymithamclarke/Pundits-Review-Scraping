# %% [markdown]
# ### Call a function to trigger the spider

# %% [markdown]
# ##### Items should be processed by the pipeline and then emerge

# %%
# Import the article scraper
import spiders.article_scraper as article_scraper

# %%
df_list = article_scraper.scrape()
# Out:
# 2020-06-17 16:51:29 [scrapy.utils.log] INFO: Scrapy 2.1.0 started (bot: matchreportscraper)
# 2020-06-17 16:51:29 [scrapy.utils.log] INFO: Versions: lxml 4.3.2.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.3 (default, Mar 27 2019, 16:54:48) - [Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1b  26 Feb 2019), cryptography 2.6.1, Platform Darwin-18.7.0-x86_64-i386-64bit
# 2020-06-17 16:51:29 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-06-17 16:51:29 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'matchreportscraper',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) '
#                'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.97 '
#                'Safari/537.36; Andy Clarke/clarkeaj3@cardiff.ac.uk'}
# ...

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('test.csv')

# %%
df
# Out:
#                          club        date field_position  n_negative  \
# 0             Manchester City  17/06/2020             DF           0
# 1             Manchester City  17/06/2020            FWD           0
# 2     Wolverhampton Wanderers  17/06/2020             DF           2
# 3           Manchester United  17/06/2020            FWD          15
# 4                     Arsenal  17/06/2020            FWD           4
# 5                     Arsenal  17/06/2020            FWD           5
# 6             Manchester City  17/06/2020            FWD           6
# 7     Wolverhampton Wanderers  17/06/2020             DF           0
# 8           Manchester United  17/06/2020             GK           1
# 9                     Arsenal  17/06/2020             MD           2
# 10    Wolverhampton Wanderers  17/06/2020            FWD           2
# 11                    Arsenal  17/06/2020             MD           4
# 12            Manchester City  17/06/2020            FWD           2
# ...

# %%
for team in d['teams']:
